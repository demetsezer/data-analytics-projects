# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Customer Order.csv')
data
# Out:
#     customer_id                company_name         contact_name  \
# 0         VINET   Vins et alcools Chevalier         Paul Henriot
# 1         TOMSP          Toms Spezialitäten        Karin Josephs
# 2         HANAR               Hanari Carnes         Mario Pontes
# 3         VICTE        Victuailles en stock         Mary Saveley
# 4         SUPRD            Suprêmes délices     Pascale Cartrain
# ..          ...                         ...                  ...
# 825       PERIC   Pericles Comidas clásicas  Guillermo Fernández
# 826       SIMOB               Simons bistro       Jytte Petersen
# 827       RICSU          Richter Supermarkt         Michael Holz
# 828       BONAP                    Bon app'     Laurence Lebihan
# 829       RATTC  Rattlesnake Canyon Grocery         Paula Wilson
#
#                       contact_title                   address            city  \
# 0                Accounting Manager        59 rue de l'Abbaye           Reims
# 1                 Marketing Manager             Luisenstr. 48         Münster
# 2                Accounting Manager           Rua do Paço, 67  Rio de Janeiro
# 3                       Sales Agent        2, rue du Commerce            Lyon
# 4                Accounting Manager      Boulevard Tirou, 255       Charleroi
# ..                              ...                       ...             ...
# 825            Sales Representative  Calle Dr. Jorge Cash 321     México D.F.
# 826                           Owner              Vinbæltet 34       Kobenhavn
# 827                   Sales Manager         Grenzacherweg 237          Genève
# 828                           Owner      12, rue des Bouchers       Marseille
# 829  Assistant Sales Representative           2817 Milton Dr.     Albuquerque
#
#     region postal_code      country              phone  ... required_date  \
# 0      NaN       51100       France        26.47.15.10  ...    1996-08-01
# 1      NaN       44087      Germany        0251-031259  ...    1996-08-16
# 2       RJ   05454-876       Brazil      (21) 555-0091  ...    1996-08-05
# 3      NaN       69004       France        78.32.54.86  ...    1996-08-05
# 4      NaN      B-6000      Belgium  (071) 23 67 22 20  ...    1996-08-06
# ..     ...         ...          ...                ...  ...           ...
# 825    NaN       05033       Mexico       (5) 552-3745  ...    1998-06-02
# 826    NaN        1734      Denmark        31 12 34 56  ...    1998-06-03
# 827    NaN        1203  Switzerland        0897-034214  ...    1998-06-03
# 828    NaN       13008       France        91.24.45.40  ...    1998-06-03
# 829     NM       87110          USA     (505) 555-5939  ...    1998-06-03
#
#      shipped_date ship_via  freight                   ship_name  \
# 0      1996-07-16        3    32.38   Vins et alcools Chevalier
# 1      1996-07-10        1    11.61          Toms Spezialitäten
# 2      1996-07-12        2    65.83               Hanari Carnes
# 3      1996-07-15        1    41.34        Victuailles en stock
# 4      1996-07-11        2    51.30            Suprêmes délices
# ..            ...      ...      ...                         ...
# 825           NaN        2    24.95   Pericles Comidas clásicas
# 826           NaN        2    18.44               Simons bistro
# 827           NaN        2     6.19          Richter Supermarkt
# 828           NaN        2    38.28                    Bon app'
# 829           NaN        2     8.53  Rattlesnake Canyon Grocery
#
#                  ship_address       ship_city  ship_region  ship_postal_code  \
# 0          59 rue de l'Abbaye           Reims          NaN             51100
# 1               Luisenstr. 48         Münster          NaN             44087
# 2             Rua do Paço, 67  Rio de Janeiro           RJ         05454-876
# 3          2, rue du Commerce            Lyon          NaN             69004
# 4        Boulevard Tirou, 255       Charleroi          NaN            B-6000
# ..                        ...             ...          ...               ...
# 825  Calle Dr. Jorge Cash 321     México D.F.          NaN             05033
# 826              Vinbæltet 34       Kobenhavn          NaN              1734
# 827               Starenweg 5          Genève          NaN              1204
# 828      12, rue des Bouchers       Marseille          NaN             13008
# 829           2817 Milton Dr.     Albuquerque           NM             87110
#
#     ship_country
# 0         France
# 1        Germany
# 2         Brazil
# 3         France
# 4        Belgium
# ..           ...
# 825       Mexico
# 826      Denmark
# 827  Switzerland
# 828       France
# 829          USA
#
# [830 rows x 25 columns]

# %%
data = data.drop(['customer_id','contact_name', 'contact_title', 'address', 'city', 'region', 'postal_code',
                   'country', 'phone', 'fax', 'employee_id', 'customer_id-2', 'ship_via', 'ship_address', 'ship_postal_code', 'ship_country','ship_region'], axis=1)
data
# Out:
#                    company_name  order_id  order_date required_date  \
# 0     Vins et alcools Chevalier     10248  1996-07-04    1996-08-01
# 1            Toms Spezialitäten     10249  1996-07-05    1996-08-16
# 2                 Hanari Carnes     10250  1996-07-08    1996-08-05
# 3          Victuailles en stock     10251  1996-07-08    1996-08-05
# 4              Suprêmes délices     10252  1996-07-09    1996-08-06
# ..                          ...       ...         ...           ...
# 825   Pericles Comidas clásicas     11073  1998-05-05    1998-06-02
# 826               Simons bistro     11074  1998-05-06    1998-06-03
# 827          Richter Supermarkt     11075  1998-05-06    1998-06-03
# 828                    Bon app'     11076  1998-05-06    1998-06-03
# 829  Rattlesnake Canyon Grocery     11077  1998-05-06    1998-06-03
#
#     shipped_date  freight                   ship_name       ship_city
# 0     1996-07-16    32.38   Vins et alcools Chevalier           Reims
# 1     1996-07-10    11.61          Toms Spezialitäten         Münster
# 2     1996-07-12    65.83               Hanari Carnes  Rio de Janeiro
# 3     1996-07-15    41.34        Victuailles en stock            Lyon
# 4     1996-07-11    51.30            Suprêmes délices       Charleroi
# ..           ...      ...                         ...             ...
# 825          NaN    24.95   Pericles Comidas clásicas     México D.F.
# 826          NaN    18.44               Simons bistro       Kobenhavn
# 827          NaN     6.19          Richter Supermarkt          Genève
# 828          NaN    38.28                    Bon app'       Marseille
# 829          NaN     8.53  Rattlesnake Canyon Grocery     Albuquerque
#
# [830 rows x 8 columns]

# %%
data['ship_duration'] = pd.to_datetime(data['shipped_date']) - pd.to_datetime(data['order_date'])
data['ship_duration'] = data['ship_duration'].dt.days
data
# Out:
#                    company_name  order_id  order_date required_date  \
# 0     Vins et alcools Chevalier     10248  1996-07-04    1996-08-01
# 1            Toms Spezialitäten     10249  1996-07-05    1996-08-16
# 2                 Hanari Carnes     10250  1996-07-08    1996-08-05
# 3          Victuailles en stock     10251  1996-07-08    1996-08-05
# 4              Suprêmes délices     10252  1996-07-09    1996-08-06
# ..                          ...       ...         ...           ...
# 825   Pericles Comidas clásicas     11073  1998-05-05    1998-06-02
# 826               Simons bistro     11074  1998-05-06    1998-06-03
# 827          Richter Supermarkt     11075  1998-05-06    1998-06-03
# 828                    Bon app'     11076  1998-05-06    1998-06-03
# 829  Rattlesnake Canyon Grocery     11077  1998-05-06    1998-06-03
#
#     shipped_date  freight                   ship_name       ship_city  \
# 0     1996-07-16    32.38   Vins et alcools Chevalier           Reims
# 1     1996-07-10    11.61          Toms Spezialitäten         Münster
# 2     1996-07-12    65.83               Hanari Carnes  Rio de Janeiro
# 3     1996-07-15    41.34        Victuailles en stock            Lyon
# 4     1996-07-11    51.30            Suprêmes délices       Charleroi
# ..           ...      ...                         ...             ...
# 825          NaN    24.95   Pericles Comidas clásicas     México D.F.
# 826          NaN    18.44               Simons bistro       Kobenhavn
# 827          NaN     6.19          Richter Supermarkt          Genève
# 828          NaN    38.28                    Bon app'       Marseille
# 829          NaN     8.53  Rattlesnake Canyon Grocery     Albuquerque
#
#      ship_duration
# 0             12.0
# 1              5.0
# 2              4.0
# 3              7.0
# 4              2.0
# ..             ...
# 825            NaN
# 826            NaN
# 827            NaN
# 828            NaN
# 829            NaN
#
# [830 rows x 9 columns]

# %%
data_grouped = data.groupby('company_name').agg({'ship_duration':'mean'})
data_grouped
# Out:
#                                     ship_duration
# company_name
# Alfreds Futterkiste                      7.333333
# Ana Trujillo Emparedados y helados       8.250000
# Antonio Moreno Taquería                  6.285714
# Around the Horn                          6.153846
# B's Beverages                            8.300000
# ...                                           ...
# Wartian Herkku                           6.266667
# Wellington Importadora                   7.555556
# White Clover Markets                    11.857143
# Wilman Kala                              4.142857
# Wolski  Zajazd                           8.000000
#
# [89 rows x 1 columns]

# %%
data_grouped = data_grouped.sort_values(by='ship_duration', ascending=False)
data_grouped
# Out:
#                               ship_duration
# company_name
# Lazy K Kountry Store              27.500000
# Galería del gastrónomo            16.800000
# Gourmet Lanchonetes               15.333333
# Hungry Coyote Import Store        12.600000
# Bólido Comidas preparadas         12.333333
# ...                                     ...
# GROSELLA-Restaurante               4.500000
# Magazzini Alimentari Riuniti       4.500000
# Familia Arquibaldo                 4.428571
# Wilman Kala                        4.142857
# North/South                        3.666667
#
# [89 rows x 1 columns]

# %%
plt.figure(figsize=(18,8))
plt.bar(data_grouped.index, data_grouped['ship_duration'])
plt.xticks(rotation=90)
plt.ylabel('Average Shipping Duration')
plt.title('Average Shipping Duration by Company')
# Out:
# Text(0.5, 1.0, 'Average Shipping Duration by Company')
